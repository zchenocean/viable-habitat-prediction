# %% [markdown]
# # Calculate pO2 using T_bar, S_bar, O2_bar

# %%
import metabolic as mi
import Phi_derivative as Pd
import xarray as xr
import numpy as np
import os
import utils
import warnings
warnings.filterwarnings('ignore')

# %%
USER = os.environ['USER']

# %% [markdown]
# ### DPLE hindcast of T,S,O2

# %%
path = f'/glade/scratch/{USER}/DPLE-results'
filename = f'{path}/DPLE-FOSI_hindcast_O2_T_S_mean_dimension_reduced_1948-2017_monthly.nc'
ds_hind = xr.open_dataset(filename)
O2_mean = ds_hind['O2_mean']
T_mean = ds_hind['T_mean']
S_mean = ds_hind['S_mean']
depth = ds_hind['3ddepth']

# %% [markdown]
# ## calculate pO2

# %%
# %%time
pO2_mean = mi.compute_pO2(O2_mean,T_mean,S_mean,depth)
# Out:
# CPU times: user 1.91 s, sys: 221 ms, total: 2.13 s
# Wall time: 4.39 s

# %%
dsf = xr.Dataset()
dsf['pO2_mean'] = pO2_mean

# %%
dout = f'/glade/scratch/{USER}/DPLE-results'
os.makedirs(dout, exist_ok=True)
dsf.load()
# Out:
# <xarray.Dataset>
# Dimensions:   (z_t: 60, nlat: 384, nlon: 320)
# Coordinates:
#   * z_t       (z_t) float32 500.0 1.5e+03 2.5e+03 ... 5.125e+05 5.375e+05
#     TLAT      (nlat, nlon) float64 -79.22 -79.22 -79.22 ... 72.2 72.19 72.19
#     TLONG     (nlat, nlon) float64 320.6 321.7 322.8 323.9 ... 318.9 319.4 319.8
#     ULAT      (nlat, nlon) float64 -78.95 -78.95 -78.95 ... 72.42 72.41 72.41
#     ULONG     (nlat, nlon) float64 321.1 322.3 323.4 324.5 ... 319.2 319.6 320.0
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     pO2_mean  (z_t, nlat, nlon) float32 nan nan nan nan nan ... nan nan nan nan

# %%
# %%time
dsf.to_netcdf(f'{dout}/DPLE-FOSI_hindcast_pO2_mean_dimension_reduced_1948-2017_monthly.nc', mode='w')
# Out:
# CPU times: user 64.1 ms, sys: 8.63 ms, total: 72.7 ms
# Wall time: 323 ms
